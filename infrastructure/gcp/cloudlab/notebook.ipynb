# %%
# %%sh
# pwd
# Out:
# /home/griffin/git/hot/infrastructure/gcp/cloudlab

# %%
# %%sh
# shell.sh -- gcloud container clusters list
# Out:
# /home/griffin/.config/shell.sh
# [/home/griffin/.config/shell.sh] [-] LOAD DEFAULT
# [/home/griffin/.config/shell.sh] [shell.env] loading scripts in bin
# guix.sh
# mount.sh
# new.sh
# repl.sh
# ssh.sh
# sync.sh
# tunnel2.sh
# tunnel3.sh
# tunnel.sh
#
# [.] [-] LOAD DEFAULT
# NAME        LOCATION  MASTER_VERSION      MASTER_IP     MACHINE_TYPE  NODE_VERSION        NUM_NODES  STATUS
# my-cluster  us-east1  1.29.4-gke.1043004  35.227.21.72  e2-small      1.29.4-gke.1043004  1          RUNNING

# %%
# %%sh
# shell.sh -- gcloud container clusters update my-cluster \
#     --location us-east1 \
#     --workload-policies=allow-net-admin
# Out:
# /home/griffin/.config/shell.sh
# [/home/griffin/.config/shell.sh] [-] LOAD DEFAULT
# [/home/griffin/.config/shell.sh] [shell.env] loading scripts in bin
#
# guix.sh
# mount.sh
# new.sh
# repl.sh
# ssh.sh
# sync.sh
# tunnel2.sh
# tunnel3.sh
# tunnel.sh
#
# [.] [-] LOAD DEFAULT
# Updating my-cluster...
# ...

# %% [markdown]
# why the hell did that take so long...
